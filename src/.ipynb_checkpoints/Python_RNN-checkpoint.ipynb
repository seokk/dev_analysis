# %%
import numpy as np
import tensorflow as tf

# 학습 : hi hello
# 주입 input : hi hell
# 예상 output : hi hello

# %%
idx2char = ['h', 'i', 'e', 'l', 'o']
# Teach hello: hihell -> ihello
# x_data = [[0, 1, 0, 2, 3, 3]]  # hihell
y_data = [[1, 0, 2, 3, 3, 4]]  # ihello

num_classes = 5 # h,i,e,l,o  5가지 classification
input_dim = 5  # one-hot size, same as hidden_size to directly predict one-hot
sequence_length = 6  # |ihello| == 6   # y_data 길이?
learning_rate = 0.1
# 학습데이터
x_one_hot = np.array([[[1, 0, 0, 0, 0],    # h 0
                       [0, 1, 0, 0, 0],    # i 1
                       [1, 0, 0, 0, 0],    # h 0
                       [0, 0, 1, 0, 0],    # e 2
                       [0, 0, 0, 1, 0],    # l 3
                       [0, 0, 0, 1, 0]]],  # l 3
                     dtype=np.float32)

# %%
y_one_hot = tf.keras.utils.to_categorical(y_data, num_classes=num_classes) #  y_data인 1 0 2 3 3 4 를 one hot encoding
# x,y 차원 확인
print(x_one_hot.shape)
print(y_one_hot.shape)
# Out:
# (1, 6, 5)
# (1, 6, 5)

# %%
tf.model = tf.keras.Sequential()

# make cell and add it to RNN layer
# input_shape = (1,6,5) => number of sequence (batch), length of sequence, size of input dim
# 5 ,6, 5  # 5개의 classification에 대해 6행 5열로 input data를 정렬
# 6개의 x_data, 5개의 classification
cell = tf.keras.layers.LSTMCell(units=num_classes, input_shape=(sequence_length, input_dim))

tf.model.add(tf.keras.layers.RNN(cell=cell, return_sequences=True))
# single LSTM layer can be used as well instead of creating LSTMCell
# tf.model.add(tf.keras.layers.LSTM(units=num_classes, input_shape=(sequence_length, input_dim), return_sequences=True))

# fully connected layer
tf.model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=num_classes, activation='softmax')))
tf.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])

# train
tf.model.fit(x_one_hot, y_one_hot, epochs=50)
tf.model.summary()

predictions = tf.model.predict(x_one_hot)

for i, prediction in enumerate(predictions):
    print(prediction)
    # print char using argmax, dict
    result_str = [idx2char[c] for c in np.argmax(prediction, axis=1)]
    print("\tPrediction str: ", ''.join(result_str))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.6585 - accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5418 - accuracy: 0.3333
# Epoch 3/50
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4536 - accuracy: 0.3333
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3512 - accuracy: 0.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2457 - accuracy: 0.5000
# Epoch 6/50
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1411 - accuracy: 0.5000
# Epoch 7/50
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0369 - accuracy: 0.6667
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9490 - accuracy: 0.6667
# Epoch 9/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8709 - accuracy: 0.6667
# Epoch 10/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7983 - accuracy: 0.6667
# Epoch 11/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7388 - accuracy: 0.6667
# Epoch 12/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6775 - accuracy: 0.8333
# Epoch 13/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6160 - accuracy: 0.8333
# Epoch 14/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5740 - accuracy: 0.8333
# Epoch 15/50
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5201 - accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4818 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4334 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4011 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3578 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3243 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2857 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2562 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2182 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1883 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1547 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1258 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1027 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0655 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0434 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    (None, 6, 5)              220
# _________________________________________________________________
# time_distributed (TimeDistri (None, 6, 5)              30
# =================================================================
# Total params: 250
# Trainable params: 250
# Non-trainable params: 0
# _________________________________________________________________
# [[3.2441588e-03 9.9571544e-01 1.0238609e-03 1.4597739e-05 1.9104946e-06]
#  [9.9471068e-01 2.2893413e-03 2.9416855e-03 2.7354958e-05 3.0822954e-05]
#  [1.6079908e-03 2.1267007e-03 9.9614644e-01 1.1891311e-04 1.1772935e-09]
#  [3.0583236e-05 5.3555222e-04 2.1425216e-03 9.9717546e-01 1.1584780e-04]
#  [4.4462586e-06 2.5861639e-06 4.4613244e-06 9.9458319e-01 5.4052686e-03]
#  [1.7506671e-05 1.4638528e-06 3.2202763e-09 9.5820529e-03 9.9039900e-01]]
# 	Prediction str:  ihello
